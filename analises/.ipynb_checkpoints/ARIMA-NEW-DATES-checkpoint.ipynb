# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import requests 
import time
import datetime as dt
from numpy import log
import statsmodels.api as sm
import statsmodels.tsa as tsa
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import r2_score

from pandas.tools.plotting import autocorrelation_plot

# statistical modeling libraries
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from scipy.stats import boxcox
#from arch import arch_model


# remove warnings
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline

# %%
def boxcox_inverse(value, lam):
	if lam == 0:
		return exp(value)
	return np.exp(np.log(lam * value + 1) / lam)

# %%
df = pd.read_csv('furtos_goiania_2.csv',index_col=0,parse_dates=True).sort_index()
df = df.loc[df.index >= '2013-01-01']
# df = df.loc[df.index <= '2017-12-01']
# df.drop('bairro', axis=1, inplace=True)
# df.drop('mes', axis=1, inplace=True)
# df.drop('ano', axis=1, inplace=True)
# df.drop('tipo', axis=1, inplace=True)
df.sort_index()
# from pandas import concat


# dataframe = concat([df['qtd'].shift(5), df['qtd'].shift(4), df['qtd'].shift(3), df['qtd'].shift(2), df['qtd'].shift(1), df['qtd']], axis=1)
# dataframe.columns = ['t-5','t-4','t-3', 't-2', 't-1', 't+1']
# print(dataframe.head(5))
# df.to_csv('goiania_out_shift_2.csv')
# Out:
#              qtd
# 0
# 2013-01-01  1141
# 2013-02-01  1121
# 2013-03-01  1213
# 2013-04-01  1266
# 2013-05-01  1377
# 2013-06-01  1436
# 2013-07-01  1116
# 2013-08-01   988
# 2013-09-01   915
# 2013-10-01  1062
# 2013-11-01  1109
# 2013-12-01  1248
# 2014-01-01  1474
# 2014-02-01  1336
# 2014-03-01  1433
# 2014-04-01  1611
# 2014-05-01  1669
# 2014-06-01  1398
# 2014-07-01  1367
# 2014-08-01  1347
# 2014-09-01  1412
# 2014-10-01  1425
# 2014-11-01  1244
# 2014-12-01  1251
# 2015-01-01  1334
# 2015-02-01  1341
# 2015-03-01  1590
# 2015-04-01  1647
# 2015-05-01  1909
# 2015-06-01  1770
# 2015-07-01  1799
# 2015-08-01  1857
# 2015-09-01  1992
# 2015-10-01  2057
# 2015-11-01  1830
# 2015-12-01  1953
# 2016-01-01  2066
# 2016-02-01  2058
# 2016-03-01  2063
# 2016-04-01  3496
# 2016-05-01  3473
# 2016-06-01  3999
# 2016-07-01  3752
# 2016-08-01  4078
# 2016-09-01  3680
# 2016-10-01  3933
# 2016-11-01  3465
# 2016-12-01  3125
# 2017-01-01  3238
# 2017-02-01  2824
# 2017-03-01  3100
# 2017-04-01  2974
# 2017-05-01  3328
# 2017-06-01  2783
# 2017-07-01  2799
# 2017-08-01  2741
# 2017-09-01  2478
# 2017-10-01  2385
# 2017-11-01  2381
# 2017-12-01  2033

# %%
def ts_diagnostics(y, lags=None, title='', filename=''):
    '''
    Calculate acf, pacf, qq plot and Augmented Dickey Fuller test for a given time series
    '''
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    # weekly moving averages (12 months window because of years)
    rolling_mean = pd.rolling_mean(y, window=12)
    rolling_std = pd.rolling_std(y, window=12)
    
    fig = plt.figure(figsize=(14, 12))
    layout = (3, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))
    qq_ax = plt.subplot2grid(layout, (2, 0))
    hist_ax = plt.subplot2grid(layout, (2, 1))
    
    # time series plot
    y.plot(ax=ts_ax)
    rolling_mean.plot(ax=ts_ax, color='crimson');
    rolling_std.plot(ax=ts_ax, color='darkslateblue');
    plt.legend(loc='best')
    ts_ax.set_title(title, fontsize=24);
    
    # acf and pacf
    smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
    smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5) 
    
    # qq plot
    sm.qqplot(y, line='s', ax=qq_ax)
    qq_ax.set_title('QQ Plot')
    
    # hist plot
    y.plot(ax=hist_ax, kind='hist', bins=25);
    hist_ax.set_title('Histogram');
    plt.tight_layout();
    
    #plot
    plt.show()
    
    # perform Augmented Dickey Fuller test
    print('Results of Dickey-Fuller test:')
    dftest = adfuller(y, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
ts_diagnostics(df['qtd'], lags=30, title='Crimes Goiânia')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.541148
# p-value                  0.513067
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64

# %%
y_diff = df['qtd'].diff(12).dropna()
ts_diagnostics(y_diff, lags=30, title='Goiaânia diff', filename='adf_diff')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.847362
# p-value                  0.357214
# # of lags                3.000000
# # of observations       44.000000
# Critical Value (1%)     -3.588573
# Critical Value (5%)     -2.929886
# Critical Value (10%)    -2.603185
# dtype: float64

# %%
y_log = np.log(df['qtd'])
ts_diagnostics(y_log, lags=30, title='Crimes na região CENTRAL Log')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.410904
# p-value                  0.577038
# # of lags                0.000000
# # of observations       59.000000
# Critical Value (1%)     -3.546395
# Critical Value (5%)     -2.911939
# Critical Value (10%)    -2.593652
# dtype: float64

# %%
y_log_diff = np.log(df['qtd']).diff().dropna()
ts_diagnostics(y_log_diff, lags=30, title='Goiânia Log Diff')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -7.741841e+00
# p-value                 1.056840e-11
# # of lags               0.000000e+00
# # of observations       5.800000e+01
# Critical Value (1%)    -3.548494e+00
# Critical Value (5%)    -2.912837e+00
# Critical Value (10%)   -2.594129e+00
# dtype: float64

# %%
y_log_diff2 = df['qtd'].diff().diff(12).dropna()

# %%
ts_diagnostics(y_log_diff2, lags=30, title='Goiânia Log 2')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -3.149584
# p-value                  0.023095
# # of lags                1.000000
# # of observations       45.000000
# Critical Value (1%)     -3.584829
# Critical Value (5%)     -2.928299
# Critical Value (10%)    -2.602344
# dtype: float64

# %%
X, lam = boxcox(df['qtd'])
ts_diagnostics(X, lags=30, title='Crimes na região CENTRAL Boxcox')
print(lam)
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.448152
# p-value                  0.558986
# # of lags                0.000000
# # of observations       59.000000
# Critical Value (1%)     -3.546395
# Critical Value (5%)     -2.911939
# Critical Value (10%)    -2.593652
# dtype: float64
# -0.4386050526405786

# %% [markdown]
# ## y_diff = np.diff(df['qtd'])

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(y_log_diff, order=(6, 1, 1))
model_fit = model.fit(disp=0)

# %%
forecast = model_fit.forecast(steps=12)[0]
print(forecast)
print(np.exp(np.r_[forecast].cumsum()))
# Out:
# [-0.06447733 -0.07186335 -0.07368746 -0.0888797  -0.06443139 -0.09143276
#  -0.09109182 -0.07809159 -0.09440022 -0.0826188  -0.09870183 -0.08253801]
# [0.93755737 0.87254532 0.81056143 0.74162775 0.69535051 0.63459264
#  0.57934113 0.53582085 0.48755332 0.44889134 0.40670131 0.37448099]

# %%
np.exp(model_fit.predict(start='2017-01-01', end='2017-12-01').cumsum())
# Out:
# 2017-01-01    1.111037
# 2017-02-01    0.974928
# 2017-03-01    1.126738
# 2017-04-01    0.920337
# 2017-05-01    1.026446
# 2017-06-01    0.820125
# 2017-07-01    1.047785
# 2017-08-01    0.916618
# 2017-09-01    0.991392
# 2017-10-01    0.978652
# 2017-11-01    1.030292
# 2017-12-01    0.950419
# Freq: MS, dtype: float64

# %%
np.exp(np.log(df['2017-01-01':'2017-12-01']['qtd']).diff().cumsum())
# Out:
# 0
# 2017-01-01         NaN
# 2017-02-01    0.872143
# 2017-03-01    0.957381
# 2017-04-01    0.918468
# 2017-05-01    1.027795
# 2017-06-01    0.859481
# 2017-07-01    0.864422
# 2017-08-01    0.846510
# 2017-09-01    0.765287
# 2017-10-01    0.736566
# 2017-11-01    0.735330
# 2017-12-01    0.627857
# Name: qtd, dtype: float64

# %%
plt.rcParams['savefig.dpi'] = 120
plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 3.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['text.usetex'] = False

# %%
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return diff

teste_dif = np.float64(difference(df['qtd'].values))

# %% [markdown]
# ## Valores sem conversão

# %%
X = df['qtd'].values
size = int(len(X) * 0.80)
size
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3,0,4))
    #3 0 4
    model_fit = model.fit(disp=0,transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
coefficient_of_dermination = r2_score(test, predictions)
print('Test R2: %.3f' % coefficient_of_dermination)
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=2852.542327, expected=3238.000000
# predicted=3044.474551, expected=2824.000000
# predicted=2828.594837, expected=3100.000000
# predicted=2793.129842, expected=2974.000000
# predicted=3140.651329, expected=3328.000000
# predicted=2982.649921, expected=2783.000000
# predicted=2757.530225, expected=2799.000000
# predicted=2529.785779, expected=2741.000000
# predicted=2638.666238, expected=2478.000000
# predicted=2472.463366, expected=2385.000000
# predicted=2307.639300, expected=2381.000000
# predicted=2316.022501, expected=2033.000000
# Test R2: 0.662
# Test MSE: 45316.603
# Test RMSE: 212.877

# %% [markdown]
# ## Valores com log

# %%
X = y_log.values
size = int(len(X) * 0.80)
size
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3, 0, 4), freq = 'M')
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))

error = mean_squared_error(np.exp(test), np.exp(predictions))
rms = sqrt(mean_squared_error(np.exp(test),np.exp(predictions)))
coefficient_of_dermination = r2_score(test, predictions)
print('Test R2: %.3f' % coefficient_of_dermination)
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(np.exp(test))
plt.plot(np.exp(predictions), color='red')
plt.show()
# Out:
# predicted=2609.537471, expected=3238.000000
# predicted=3407.006887, expected=2824.000000
# predicted=2056.759128, expected=3100.000000
# predicted=2850.183464, expected=2974.000000
# predicted=2841.603873, expected=3328.000000
# predicted=2842.196332, expected=2783.000000
# predicted=2657.578274, expected=2799.000000
# predicted=2819.068568, expected=2741.000000
# predicted=2566.728595, expected=2478.000000
# predicted=2285.609547, expected=2385.000000
# predicted=2242.161470, expected=2381.000000
# predicted=2252.911150, expected=2033.000000
# Test R2: -0.311
# Test MSE: 182509.393
# Test RMSE: 427.211

# %% [markdown]
# ## Valores com BoxCox

# %%
X = df['qtd'].values
X = X.astype('float32')
train_size = int(len(X) * 0.80)
train, test = X[0:train_size], X[train_size:]

# walk-foward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# transform
	transformed, lam = boxcox(history)
	if lam < -5:
		transformed, lam = history, 1
	# predict
	model = ARIMA(transformed, order=(3,0,2))
	model_fit = model.fit(disp=0, transparams=False)
	yhat = model_fit.forecast()[0]
	# invert transformed prediction
	yhat = boxcox_inverse(yhat, lam)
	predictions.append(yhat)
	# observation
	obs = test[i]
	history.append(obs)
	print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
mse = mean_squared_error(np.float64(test),np.float64(predictions))
rmse = sqrt(mse)

print('RMSE: %.3f' % rmse)
plt.plot(np.float64(test))
plt.plot(np.float64(predictions), color='red')
plt.show()
# Out:
# >Predicted=2449.243, Expected=3238.000
# >Predicted=3043.710, Expected=2824.000
# >Predicted=2622.379, Expected=3100.000
# >Predicted=2943.978, Expected=2974.000
# >Predicted=2952.603, Expected=3328.000
# >Predicted=3003.182, Expected=2783.000
# >Predicted=2691.500, Expected=2799.000
# >Predicted=2691.226, Expected=2741.000
# >Predicted=2647.633, Expected=2478.000
# >Predicted=2412.196, Expected=2385.000
# >Predicted=2322.388, Expected=2381.000
# >Predicted=2415.109, Expected=2033.000
# RMSE: 326.832

# %% [markdown]
# ## Valores com diff

# %%
X = y_log_diff2.values
first = X[0]
# X = np.diff(X)
X = X.astype('float32')
train_size = int(len(X) * 0.80)
train, test = X[0:train_size], X[train_size:]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(4, 0, 2))
    model_fit = model.fit(disp=0, transparams=True)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
coefficient_of_dermination = r2_score(test, predictions)
print('Test R2: %.3f' % coefficient_of_dermination)
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=nan, expected=271.000000
# predicted=nan, expected=-1559.000000
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-60-b5787a0f4e9c> in <module>()
#       3 for t in range(len(test)):
#       4     model = ARIMA(history, order=(4, 0, 2))
# ----> 5     model_fit = model.fit(disp=0, transparams=True)
#       6     output = model_fit.forecast()
#       7     yhat = output[0]
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in fit(self, start_params, trend, method, transparams, solver, maxiter, full_output, disp, callback, start_ar_lags, **kwargs)
#     967                                        maxiter=maxiter,
#     968                                        full_output=full_output, disp=disp,
# --> 969                                        callback=callback, **kwargs)
#     970         params = mlefit.params
#     971
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     449                                                        callback=callback,
#     450                                                        retall=retall,
# --> 451                                                        full_output=full_output)
#     452
#     453         #NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     182                             disp=disp, maxiter=maxiter, callback=callback,
#     183                             retall=retall, full_output=full_output,
# --> 184                             hess=hessian)
#     185
#     186         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     376                                          callback=callback, args=fargs,
#     377                                          bounds=bounds, disp=disp,
# --> 378                                          **extra_kwargs)
#     379
#     380     if full_output:
#
# ~/anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     278     if jac is None:
#     279         def func_and_grad(x):
# --> 280             f = fun(x, *args)
#     281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#
# ~/anaconda/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     290     def function_wrapper(*wrapper_args):
#     291         ncalls[0] += 1
# --> 292         return function(*(wrapper_args + args))
#     293
#     294     return ncalls, function_wrapper
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/base/model.py in <lambda>(params, *args)
#     427
#     428         nobs = self.endog.shape[0]
# --> 429         f = lambda params, *args: -self.loglike(params, *args) / nobs
#     430         score = lambda params, *args: -self.score(params, *args) / nobs
#     431         try:
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in loglike(self, params, set_sigma2)
#     788         method = self.method
#     789         if method in ['mle', 'css-mle']:
# --> 790             return self.loglike_kalman(params, set_sigma2)
#     791         elif method == 'css':
#     792             return self.loglike_css(params, set_sigma2)
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/tsa/arima_model.py in loglike_kalman(self, params, set_sigma2)
#     798         Compute exact loglikelihood for ARMA(p,q) model by the Kalman Filter.
#     799         """
# --> 800         return KalmanFilter.loglike(params, self, set_sigma2)
#     801
#     802     def loglike_css(self, params, set_sigma2=True):
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/tsa/kalmanf/kalmanfilter.py in loglike(cls, params, arma_model, set_sigma2)
#     647             loglike, sigma2 =  kalman_loglike.kalman_loglike_double(y, k,
#     648                                     k_ar, k_ma, k_lags, int(nobs), Z_mat,
# --> 649                                     R_mat, T_mat)
#     650         elif issubdtype(paramsdtype, complex):
#     651             loglike, sigma2 =  kalman_loglike.kalman_loglike_complex(y, k,
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_loglike_double (statsmodels/tsa/kalmanf/kalman_loglike.c:6510)()
#
# statsmodels\tsa\kalmanf\kalman_loglike.pyx in statsmodels.tsa.kalmanf.kalman_loglike.kalman_filter_double (statsmodels/tsa/kalmanf/kalman_loglike.c:3560)()
#
# ~/anaconda/lib/python3.6/site-packages/numpy/linalg/linalg.py in pinv(a, rcond)
#    1722         return wrap(res)
#    1723     a = a.conjugate()
# -> 1724     u, s, vt = svd(a, full_matrices=False)
#    1725
#    1726     # discard small singular values
#
# ~/anaconda/lib/python3.6/site-packages/numpy/linalg/linalg.py in svd(a, full_matrices, compute_uv)
#    1442
#    1443         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1444         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1445         u = u.astype(result_t, copy=False)
#    1446         s = s.astype(_realType(result_t), copy=False)
#
# ~/anaconda/lib/python3.6/site-packages/numpy/linalg/linalg.py in _raise_linalgerror_svd_nonconvergence(err, flag)
#      96
#      97 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 98     raise LinAlgError("SVD did not converge")
#      99
#     100 def get_linalg_error_extobj(callback):
#
# LinAlgError: SVD did not converge

# %%
from numpy import mean
X = df['qtd'].values
window = 2
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions)) 
print('Test RMSE: %.3f' % rmse)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# zoom plot
# plt.plot(test[:100])
# plt.plot(predictions[:100], color='red')
# plt.show()
# Out:
# predicted=1131.000000, expected=1213.000000
# predicted=1167.000000, expected=1266.000000
# predicted=1239.500000, expected=1377.000000
# predicted=1321.500000, expected=1436.000000
# predicted=1406.500000, expected=1116.000000
# predicted=1276.000000, expected=988.000000
# predicted=1052.000000, expected=915.000000
# predicted=951.500000, expected=1062.000000
# predicted=988.500000, expected=1109.000000
# predicted=1085.500000, expected=1248.000000
# predicted=1178.500000, expected=1474.000000
# predicted=1361.000000, expected=1336.000000
# predicted=1405.000000, expected=1433.000000
# predicted=1384.500000, expected=1611.000000
# predicted=1522.000000, expected=1669.000000
# predicted=1640.000000, expected=1398.000000
# predicted=1533.500000, expected=1367.000000
# predicted=1382.500000, expected=1347.000000
# predicted=1357.000000, expected=1412.000000
# predicted=1379.500000, expected=1425.000000
# predicted=1418.500000, expected=1244.000000
# predicted=1334.500000, expected=1251.000000
# predicted=1247.500000, expected=1334.000000
# predicted=1292.500000, expected=1341.000000
# predicted=1337.500000, expected=1590.000000
# predicted=1465.500000, expected=1647.000000
# predicted=1618.500000, expected=1909.000000
# predicted=1778.000000, expected=1770.000000
# predicted=1839.500000, expected=1799.000000
# predicted=1784.500000, expected=1857.000000
# predicted=1828.000000, expected=1992.000000
# predicted=1924.500000, expected=2057.000000
# predicted=2024.500000, expected=1830.000000
# predicted=1943.500000, expected=1953.000000
# predicted=1891.500000, expected=2066.000000
# predicted=2009.500000, expected=2058.000000
# predicted=2062.000000, expected=2063.000000
# predicted=2060.500000, expected=3496.000000
# predicted=2779.500000, expected=3473.000000
# predicted=3484.500000, expected=3999.000000
# predicted=3736.000000, expected=3752.000000
# predicted=3875.500000, expected=4078.000000
# predicted=3915.000000, expected=3680.000000
# predicted=3879.000000, expected=3933.000000
# predicted=3806.500000, expected=3465.000000
# predicted=3699.000000, expected=3125.000000
# predicted=3295.000000, expected=3238.000000
# predicted=3181.500000, expected=2824.000000
# predicted=3031.000000, expected=3100.000000
# predicted=2962.000000, expected=2974.000000
# predicted=3037.000000, expected=3328.000000
# predicted=3151.000000, expected=2783.000000
# predicted=3055.500000, expected=2799.000000
# predicted=2791.000000, expected=2741.000000
# predicted=2770.000000, expected=2478.000000
# predicted=2609.500000, expected=2385.000000
# predicted=2431.500000, expected=2381.000000
# predicted=2383.000000, expected=2033.000000
# Test RMSE: 291.531

# %%
from pandas import Series

stationary = difference(df['qtd'].values).dropna()
# stationary.index = series.index[1:]
# check if stationary
result = adfuller(stationary) 
print('ADF Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) # save
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-e4a8fac5bd84> in <module>()
#       1 from pandas import Series
#       2
# ----> 3 stationary = difference(df['qtd'].values).dropna()
#       4 # stationary.index = series.index[1:]
#       5 # check if stationary
#
# AttributeError: 'list' object has no attribute 'dropna'

# %% [markdown]
# ## Analizar order Arima

# %%
# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	X = X.astype('float32')
	train_size = int(len(X) * 0.80)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
        
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit(disp=0,trend='nc',transparams=False)
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	mse = mean_squared_error(test, predictions)
	rmse = sqrt(mse)
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					mse = evaluate_arima_model(dataset, order)
					if mse < best_score:
						best_score, best_cfg = mse, order
					print('ARIMA%s MSE=%.3f' % (order,mse))
				except:
					continue
	print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# load dataset

# evaluate parameters
p_values = range(0,6)
d_values = range(0, 4)
q_values = range(0, 6)
warnings.filterwarnings("ignore")
X, lam = boxcox(df['qtd'].values)
# evaluate_models(df['qtd'].values, p_values, d_values, q_values)

# %%
# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model_boxcox(X, arima_order):
	# prepare training dataset
	X = X.astype('float32')
	train_size = int(len(X) * 0.85)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		transformed, lam = boxcox(history)
		if lam < -5:
			transformed, lam = history, 1
		model = ARIMA(transformed, order=arima_order)
		model_fit = model.fit(disp=0,transparams=False)
		yhat = model_fit.forecast()[0]
		yhat = boxcox_inverse(yhat, lam)
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	mse = mean_squared_error(test, predictions)
	rmse = sqrt(mse)
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models_boxcox(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					mse = evaluate_arima_model_boxcox(dataset, order)
					if mse < best_score:
						best_score, best_cfg = mse, order
					print('ARIMA%s MSE=%.3f' % (order,mse))
				except:
					continue
	print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# evaluate_models_boxcox(df['qtd'].values, p_values, d_values, q_values)

# %%
diff = np.diff(df['qtd'].values)

# %%
np.r_[1141, diff].cumsum()
# Out:
# array([1141, 1121, 1213, 1266, 1377, 1436, 1116,  988,  915, 1062, 1109,
#        1248, 1474, 1336, 1433, 1611, 1669, 1398, 1367, 1347, 1412, 1425,
#        1244, 1251, 1334, 1341, 1590, 1647, 1909, 1770, 1799, 1857, 1992,
#        2057, 1830, 1953, 2066, 2058, 2063, 3496, 3473, 3999, 3752, 4078,
#        3680, 3933, 3465, 3125, 3238, 2824, 3100, 2974, 3328, 2783, 2799,
#        2741, 2478, 2385, 2381, 2033])

# %%
X = df['qtd'].values
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=1351.666667, mean2=2791.333333
# variance1=50564.022222, variance2=518006.355556

# %%
import pyflux as pf

# %%
train, test = df['2013-01-01':'2016-12-01'], df['2017-01-01':]

model = pf.ARIMAX(data=train, formula='qtd~1',ar=1, ma=1, family=pf.Normal())
x = model.fit("MLE")
x.summary()
model.plot_fit()
# model.plot_predict(h=12,oos_data=df.iloc[-12:],past_values=58)
temp = model.predict(h=12,oos_data=df.iloc[-12:])
print (type(temp))
print (temp)
plt.plot(test)
plt.plot(temp, color='red')
plt.show()
# Out:
# Normal ARIMAX(1,0,1)
# ======================================================= ==================================================
# Dependent Variable: qtd                                 Method: MLE
# Start Date: 2013-02-01 00:00:00                         Log Likelihood: -331.4274
# End Date: 2016-12-01 00:00:00                           AIC: 670.8548
# Number of observations: 47                              BIC: 678.2554
# ==========================================================================================================
# Latent Variable                          Estimate   Std Error  z        P>|z|    95% C.I.
# ======================================== ========== ========== ======== ======== =========================
# AR(1)                                    1.014      0.0423     23.95    0.0      (0.931 | 1.097)
# MA(1)                                    -0.094     0.1242     -0.7566  0.4493   (-0.3374 | 0.1495)
# Beta 1                                   0.0024     88.1304    0.0      1.0      (-172.7332 | 172.738)
# Normal Scale                             279.4169
# ==========================================================================================================
# <class 'pandas.core.frame.DataFrame'>
#                     qtd
# 0
# 2016-12-26  3209.749779
# 2017-01-26  3254.688647
# 2017-02-24  3300.256659
# 2017-03-27  3346.462622
# 2017-04-26  3393.315468
# 2017-05-27  3440.824254
# 2017-06-26  3488.998162
# 2017-07-27  3537.846504
# 2017-08-27  3587.378722
# 2017-09-26  3637.604391
# 2017-10-27  3688.533219
# 2017-11-26  3740.175050

# %%
from statsmodels.tsa.vector_ar.var_model import VAR

# %%
model = VAR(df)
results = model.fit(0)
results.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-64b9cf7a2179> in <module>()
# ----> 1 model = VAR(df)
#       2 results = model.fit(0)
#       3 results.summary()
#
# ~/anaconda/lib/python3.6/site-packages/statsmodels/tsa/vector_ar/var_model.py in __init__(self, endog, dates, freq, missing)
#     332         super(VAR, self).__init__(endog, None, dates, freq, missing=missing)
#     333         if self.endog.ndim == 1:
# --> 334             raise ValueError("Only gave one variable to VAR")
#     335         self.y = self.endog #keep alias for now
#     336         self.neqs = self.endog.shape[1]
#
# ValueError: Only gave one variable to VAR

# %%
X = df['qtd'].values
X = X.astype('float32')
train_size = int(len(X) * 0.85)
train, test = X[0:train_size], X[train_size:]
# train, test = df['2013-01-01':'2016-12-02'], df['2017-01-01':]
mod = sm.tsa.statespace.SARIMAX(train,
                                order=(1, 1, 0),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=True,
                                enforce_invertibility=False)

results = mod.fit()
print(len(train))
# Out:
# 51

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=52, end=60, dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = test
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('CO2 Levels')
plt.legend()

plt.show()
# print(pred_ci.iloc[:, 1])
# print(test)
# predictions = pred_ci.iloc[:, 1]
# error = mean_squared_error(test, predictions)
# rms = sqrt(mean_squared_error(test, predictions))
# coefficient_of_dermination = r2_score(test, predictions)
# print('Test R2: %.3f' % coefficient_of_dermination)
# print('Test MSE: %.3f' % error)
# print('Test RMSE: %.3f' % rms)
# # plot
# plt.plot(test)
# plt.plot(predictions, color='red')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-78f9c01ade68> in <module>()
#       1 ax = test
# ----> 2 pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)
#       3
#       4 ax.fill_between(pred_ci.index,
#       5                 pred_ci.iloc[:, 0],
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
import itertools

p = d = q = range(0, 2)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df['qtd'].values,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:824.7137419796668
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1365.6594559273142
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:802.6856748865447
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:773.521727912303
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:612.2996662520277
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:598.2734873179572
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:998.2384572933552
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:773.25361229178
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:743.0181633964897
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1680.5366980913202
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:775.3511234626025
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:734.0833247073814
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:589.1484838182568
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:560.3451696870476
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:661.854420626605
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1414.54737185786
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:675.3558875096039
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:663.8533366622321
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:511.97986036121625
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:1356.2371239184483
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:809.0188769231253
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:649.2839525993994
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:672.7191014695733
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1606.7905416460558
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:675.9776106333032
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:651.2278548314792
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:513.0916952932722
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:1507.324476966499
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:836.5365517354768
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:677.3007034862937
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:703.4006168378962
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:1172.1704231197168
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:677.3065481712748
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:679.2964848153358
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:513.4416080831484
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:514.4189435137657
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:824.2883917377399
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:664.6661509211951
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:687.9007959519608
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:1437.776258231036
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:678.3126835369944
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:666.5854314221896
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:514.6460596126992
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:502.16411338412223
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:821.4418788337756
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:661.5146636893243
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:681.9015891184171
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1466.30678441354
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:661.2570845703953
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:663.2137254804452
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:498.5152528550918
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:1392.6532905976214
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:806.7514383759178
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:646.589735708437
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:663.6888604425388
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1387.8984838473605
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:659.1156017568389
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:647.8271152205382
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:495.81346933807936
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:1310.9570585020615

# %%
from pandas import Series

series = Series.from_csv('furtos_goiania_2.csv', header=0)
# series = 
X = series[:'2018-12-01'].values
X = X.astype('float32')

model = ARIMA(X, order=(3, 0, 4))
model.dates = None
model.freq = 'c'
model.missing = None
model_fit = model.fit(disp=0, transparams=False, start_ar_lags=13)
model_fit.save('model.pkl')

# %%
from statsmodels.tsa.arima_model import ARIMAResults
loaded = ARIMAResults.load('model.pkl')

# %%
print(loaded.forecast(steps=12)[0])
# Out:
# [1961.40872545 1825.50234713 1736.97924262 1667.08313152 1638.83977216
#  1600.04100937 1579.67927795 1563.5952562  1550.19534804 1542.10073043
#  1535.19296365 1530.40141494]

# %%
size = len(X)
print(size)
forecast = loaded.predict(start=size, end=size+11)
print(forecast)
# Out:
# 96
# [1961.40872545 1825.50234713 1736.97924262 1667.08313152 1638.83977216
#  1600.04100937 1579.67927795 1563.5952562  1550.19534804 1542.10073043
#  1535.19296365 1530.40141494]

# %%
from pandas import Series
def difference(dataset):
	diff = list()
	for i in range(1, len(dataset)):
		value = dataset[i] - dataset[i - 1]
		diff.append(value)
	return Series(diff)

# %%
series = Series.from_csv('furtos_goiania_2.csv', header=0)
X = difference(series)

# %%
X = series.values
X = X.astype('float32')
# difference data
stationary = difference(X)
stationary.index = series.index[1:]
# check if stationary
result = adfuller(stationary)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# plot differenced data
stationary.plot()
plt.show()
# Out:
# ADF Statistic: -5.351201
# p-value: 0.000004
# Critical Values:
# 	1%: -3.503
# 	5%: -2.893
# 	10%: -2.584

# %%
evaluate_models(stationary, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 1) MSE=311.255
# ARIMA(0, 0, 2) MSE=286.462
# ARIMA(0, 0, 3) MSE=297.981
# ARIMA(0, 0, 4) MSE=302.263
# ARIMA(0, 0, 5) MSE=284.925
# ARIMA(0, 1, 1) MSE=330.004
# ARIMA(0, 2, 1) MSE=529.397
# ARIMA(1, 0, 0) MSE=311.936
# ARIMA(1, 1, 0) MSE=386.668
# ARIMA(1, 1, 1) MSE=338.373
# ARIMA(1, 2, 0) MSE=676.398
# ARIMA(2, 0, 0) MSE=296.836
# ARIMA(2, 0, 1) MSE=301.315
# ARIMA(2, 1, 0) MSE=401.848
# ARIMA(2, 1, 1) MSE=313.903
# ARIMA(2, 2, 0) MSE=56134279101.183
# ARIMA(2, 2, 1) MSE=520.614
# ARIMA(3, 0, 0) MSE=302.645
# ARIMA(3, 0, 1) MSE=307.110
# ARIMA(3, 0, 2) MSE=311.224
# ARIMA(3, 1, 0) MSE=1092733876626.847
# ARIMA(3, 1, 1) MSE=345.785
# ARIMA(3, 2, 0) MSE=510.705
# ARIMA(3, 2, 1) MSE=470.538
# ARIMA(4, 0, 0) MSE=301.370
# ARIMA(4, 0, 1) MSE=305.544
# ARIMA(4, 0, 2) MSE=303.884
# ARIMA(4, 1, 0) MSE=390.428
# ARIMA(4, 1, 1) MSE=355.814
# ARIMA(4, 2, 0) MSE=484.315
# ARIMA(5, 0, 0) MSE=296.940
# ARIMA(5, 0, 1) MSE=295.694
# ARIMA(5, 0, 2) MSE=283.879
# ARIMA(5, 0, 3) MSE=290.162
# ARIMA(5, 0, 4) MSE=460.641
# ARIMA(5, 1, 0) MSE=385.292
# ARIMA(5, 1, 1) MSE=352.277
# ARIMA(5, 1, 2) MSE=319.572
# ARIMA(5, 2, 0) MSE=487.680
# Best ARIMA(5, 0, 2) MSE=283.879

# %%
X = stationary
size = int(len(X) * 0.80)
size
train, test = X[0:size], X[size:len(X)]
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(5, 0, 2))
    #3 0 4
    model_fit = model.fit(disp=0,transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
coefficient_of_dermination = r2_score(test, predictions)
print('Test R2: %.3f' % coefficient_of_dermination)
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
# plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=95.394318, expected=526.000000
# predicted=74.873958, expected=-247.000000
# predicted=202.552256, expected=326.000000
# predicted=-242.356193, expected=-398.000000
# predicted=86.848498, expected=253.000000
# predicted=-66.853675, expected=-468.000000
# predicted=136.004708, expected=-340.000000
# predicted=-42.189533, expected=113.000000
# predicted=82.575705, expected=-414.000000
# predicted=204.938960, expected=276.000000
# predicted=13.322694, expected=-126.000000
# predicted=139.388009, expected=354.000000
# predicted=-110.020478, expected=-545.000000
# predicted=299.686479, expected=16.000000
# predicted=-242.644182, expected=-58.000000
# predicted=127.525505, expected=-263.000000
# predicted=-13.466620, expected=-93.000000
# predicted=47.697441, expected=-4.000000
# predicted=75.397219, expected=-348.000000
# Test R2: 0.035
# Test MSE: 91017.677
# Test RMSE: 301.691

# %%
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
model = ARIMA(history, order=(5, 0, 2))
model_fit = model.fit(disp=0,transparams=False)
print(model_fit.forecast()[0])
# Out:
# [-130.79525425]
