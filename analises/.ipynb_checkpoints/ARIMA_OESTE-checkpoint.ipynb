# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import requests 
import time
import datetime as dt
from numpy import log
import statsmodels.api as sm
import statsmodels.tsa as tsa
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from math import sqrt

from pandas.tools.plotting import autocorrelation_plot

# statistical modeling libraries
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from scipy.stats import boxcox
#from arch import arch_model


# remove warnings
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline
# Out:
# /Users/diogodil/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def boxcox_inverse(value, lam):
	if lam == 0:
		return np.exp(value)
	return np.exp(np.log(lam * value + 1) / lam)

# %%
df = pd.read_csv('roubos.csv',index_col=0,parse_dates=True).sort_index()
df = df.loc[df['ano'] > 2012]
df = df.loc[df['bairro'] == 'LESTE']
df.drop('bairro', axis=1, inplace=True)
df.drop('mes', axis=1, inplace=True)
df.drop('ano', axis=1, inplace=True)
df.drop('tipo', axis=1, inplace=True)
df.sort_index()
df.head()
# Out:
#             qtd
# 0
# 2013-01-01   81
# 2013-02-01   74
# 2013-03-01   78
# 2013-04-01  106
# 2013-05-01  118

# %%
def ts_diagnostics(y, lags=None, title='', filename=''):
    '''
    Calculate acf, pacf, qq plot and Augmented Dickey Fuller test for a given time series
    '''
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    # weekly moving averages (12 months window because of years)
    rolling_mean = pd.rolling_mean(y, window=12)
    rolling_std = pd.rolling_std(y, window=12)
    
    fig = plt.figure(figsize=(14, 12))
    layout = (3, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))
    qq_ax = plt.subplot2grid(layout, (2, 0))
    hist_ax = plt.subplot2grid(layout, (2, 1))
    
    # time series plot
    y.plot(ax=ts_ax)
    rolling_mean.plot(ax=ts_ax, color='crimson');
    rolling_std.plot(ax=ts_ax, color='darkslateblue');
    plt.legend(loc='best')
    ts_ax.set_title(title, fontsize=24);
    
    # acf and pacf
    smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
    smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5) 
    
    # qq plot
    sm.qqplot(y, line='s', ax=qq_ax)
    qq_ax.set_title('QQ Plot')
    
    # hist plot
    y.plot(ax=hist_ax, kind='hist', bins=25);
    hist_ax.set_title('Histogram');
    plt.tight_layout();
    
    #plot
    plt.show()
    
    # perform Augmented Dickey Fuller test
    print('Results of Dickey-Fuller test:')
    dftest = adfuller(y, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
ts_diagnostics(df['qtd'], lags=30, title='Crimes Goiânia')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.921390
# p-value                  0.322067
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64

# %%
y_diff = np.diff(df['qtd'])
ts_diagnostics(y_diff, lags=30, title='Goiaânia diff', filename='adf_diff')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -8.831227e+00
# p-value                 1.767596e-14
# # of lags               1.000000e+00
# # of observations       5.700000e+01
# Critical Value (1%)    -3.550670e+00
# Critical Value (5%)    -2.913766e+00
# Critical Value (10%)   -2.594624e+00
# dtype: float64

# %%
y_log = np.log(df['qtd'])
ts_diagnostics(y_log, lags=30, title='Crimes na região CENTRAL Log')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -2.230286
# p-value                  0.195438
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64

# %%
y_log_diff = np.log(df['qtd']).diff().dropna()
ts_diagnostics(y_log_diff, lags=30, title='Goiânia Log Diff')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -8.177280e+00
# p-value                 8.311467e-13
# # of lags               1.000000e+00
# # of observations       5.700000e+01
# Critical Value (1%)    -3.550670e+00
# Critical Value (5%)    -2.913766e+00
# Critical Value (10%)   -2.594624e+00
# dtype: float64

# %%
y_log_diff2 = np.log(df['qtd']).diff().diff(12).dropna()

# %%
ts_diagnostics(y_log_diff2, lags=30, title='Goiânia Log 2')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -6.436511e+00
# p-value                 1.647747e-08
# # of lags               2.000000e+00
# # of observations       4.400000e+01
# Critical Value (1%)    -3.588573e+00
# Critical Value (5%)    -2.929886e+00
# Critical Value (10%)   -2.603185e+00
# dtype: float64

# %%
df['qtd_box'], lam = boxcox(df['qtd'])
ts_diagnostics(df['qtd_box'].dropna(), lags=30, title='Crimes na região CENTRAL Boxcox')
print(lam)
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -2.008682
# p-value                  0.282779
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64
# 0.6898492981834187

# %%
y_diff = np.diff(df['qtd'])

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(y_log_diff, order=(6, 1, 1))
model_fit = model.fit(disp=0)

# %%
forecast = model_fit.forecast(steps=12)[0]
print(forecast)
print(np.exp(np.r_[forecast].cumsum()))
# Out:
# [ 0.00602962  0.1002132  -0.02351167 -0.07930287 -0.08592143  0.02114336
#  -0.03976875 -0.07754373 -0.04526499 -0.031677   -0.03737152 -0.06350987]
# [1.00604784 1.11209189 1.08624974 1.00343417 0.92081776 0.94049422
#  0.9038259  0.83638833 0.79937329 0.7744484  0.74604022 0.70013253]

# %%
np.exp(model_fit.predict(start='2017-01-01', end='2017-12-01').cumsum())
# Out:
# 2017-01-01    1.384874
# 2017-02-01    1.122463
# 2017-03-01    1.111062
# 2017-04-01    1.163219
# 2017-05-01    1.154634
# 2017-06-01    1.095234
# 2017-07-01    1.230849
# 2017-08-01    1.295872
# 2017-09-01    1.385149
# 2017-10-01    1.374513
# 2017-11-01    1.219306
# 2017-12-01    1.027721
# Freq: MS, dtype: float64

# %%
np.exp(np.log(df['2017-01-01':'2017-12-01']['qtd']).diff().cumsum())
# Out:
# 0
# 2017-01-01         NaN
# 2017-02-01    0.967320
# 2017-03-01    0.895425
# 2017-04-01    0.875817
# 2017-05-01    0.921569
# 2017-06-01    0.784314
# 2017-07-01    0.764706
# 2017-08-01    0.725490
# 2017-09-01    0.725490
# 2017-10-01    0.758170
# 2017-11-01    0.816993
# 2017-12-01    0.555556
# Name: qtd, dtype: float64

# %%
plt.rcParams['savefig.dpi'] = 120
plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 3.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['text.usetex'] = False

# %%
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return diff

teste_dif = np.float64(difference(df['qtd'].values))

# %% [markdown]
# ## Valores sem conversão

# %%
X = df['qtd'].values
size = int(len(X) * 0.85)
size
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3, 2, 1))
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=134.284863, expected=134.000000
# predicted=137.350288, expected=141.000000
# predicted=137.122940, expected=120.000000
# predicted=120.421002, expected=117.000000
# predicted=120.974643, expected=111.000000
# predicted=111.756420, expected=111.000000
# predicted=106.503019, expected=116.000000
# predicted=107.084000, expected=125.000000
# predicted=111.597998, expected=85.000000
# Test MSE: 170.777
# Test RMSE: 13.068

# %% [markdown]
# ## Valores com log

# %%
X = y_log.values
size = int(len(X) * 0.85)
size
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3, 2, 2), freq = 'M')
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))

error = mean_squared_error(np.exp(test), np.exp(predictions))
rms = sqrt(mean_squared_error(np.exp(test),np.exp(predictions)))
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(np.exp(test))
plt.plot(np.exp(predictions), color='red')
plt.show()
# Out:
# predicted=137.483651, expected=134.000000
# predicted=135.308316, expected=141.000000
# predicted=138.039386, expected=120.000000
# predicted=119.802136, expected=117.000000
# predicted=119.491468, expected=111.000000
# predicted=112.404389, expected=111.000000
# predicted=108.765249, expected=116.000000
# predicted=110.918402, expected=125.000000
# predicted=113.324142, expected=85.000000
# Test MSE: 167.197
# Test RMSE: 12.930

# %% [markdown]
# ## Valores com BoxCox

# %%
X = df['qtd'].values
train_size = int(len(X) * 0.85)
train, test = X[0:train_size], X[train_size:]

# walk-foward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# transform
	transformed, lam = boxcox(history)
	if lam < -5:
		transformed, lam = history, 1
	# predict
	model = ARIMA(transformed, order=(2, 2, 1))
	model_fit = model.fit(disp=0, transparams=False)
	yhat = model_fit.forecast()[0]
	# invert transformed prediction
	yhat = boxcox_inverse(yhat, lam)
	predictions.append(yhat)
	# observation
	obs = test[i]
	history.append(obs)
	print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
mse = mean_squared_error(np.float64(test),np.float64(predictions))
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# >Predicted=139.348, Expected=134.000
# >Predicted=135.772, Expected=141.000
# >Predicted=135.966, Expected=120.000
# >Predicted=118.986, Expected=117.000
# >Predicted=121.356, Expected=111.000
# >Predicted=107.803, Expected=111.000
# >Predicted=106.965, Expected=116.000
# >Predicted=108.202, Expected=125.000
# >Predicted=114.672, Expected=85.000
# RMSE: 13.648

# %% [markdown]
# ## Valores com diff

# %%
X = df['qtd'].values
first = X[0]
X = np.diff(X)
X = X.astype('float32')
train_size = int(len(X) * 0.85)
train, test = X[0:train_size], X[train_size:]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3, 1, 1))
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=-2.715137, expected=-3.000000
# predicted=3.350288, expected=7.000000
# predicted=-3.877060, expected=-21.000000
# predicted=0.421002, expected=-3.000000
# predicted=3.974643, expected=-6.000000
# predicted=0.756420, expected=0.000000
# predicted=-4.496981, expected=5.000000
# predicted=-8.916000, expected=9.000000
# predicted=-13.402002, expected=-40.000000
# Test MSE: 170.777
# Test RMSE: 13.068

# %%
from numpy import mean
X = y_log.values
window = 3
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions)) 
print('Test RMSE: %.3f' % rmse)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
# plt.show()
# # zoom plot
# plt.plot(test[:100])
# plt.plot(predictions[:100], color='red')
# plt.show()
# Out:
# predicted=4.351741, expected=4.663439
# predicted=4.441404, expected=4.770685
# predicted=4.596944, expected=4.744932
# predicted=4.726352, expected=4.454347
# predicted=4.656655, expected=4.682131
# predicted=4.627137, expected=4.488636
# predicted=4.541705, expected=4.343805
# predicted=4.504858, expected=4.477337
# predicted=4.436593, expected=4.736198
# predicted=4.519114, expected=4.941642
# predicted=4.718393, expected=4.812184
# predicted=4.830008, expected=4.634729
# predicted=4.796185, expected=4.890349
# predicted=4.779087, expected=5.049856
# predicted=4.858311, expected=4.736198
# predicted=4.892135, expected=4.605170
# predicted=4.797075, expected=4.584967
# predicted=4.642112, expected=4.787492
# predicted=4.659210, expected=4.955827
# predicted=4.776095, expected=4.820282
# predicted=4.854533, expected=4.653960
# predicted=4.810023, expected=4.836282
# predicted=4.770175, expected=4.934474
# predicted=4.808239, expected=4.955827
# predicted=4.908861, expected=4.997212
# predicted=4.962504, expected=5.062595
# predicted=5.005211, expected=5.159055
# predicted=5.072954, expected=4.976734
# predicted=5.066128, expected=5.023881
# predicted=5.053223, expected=5.129899
# predicted=5.043504, expected=5.347108
# predicted=5.166962, expected=5.147494
# predicted=5.208167, expected=5.003946
# predicted=5.166183, expected=5.283204
# predicted=5.144882, expected=5.129899
# predicted=5.139016, expected=5.093750
# predicted=5.168951, expected=5.209486
# predicted=5.144378, expected=5.049856
# predicted=5.117697, expected=5.153292
# predicted=5.137545, expected=5.129899
# predicted=5.111015, expected=5.236442
# predicted=5.173211, expected=5.017280
# predicted=5.127874, expected=5.056246
# predicted=5.103323, expected=5.081404
# predicted=5.051643, expected=4.820282
# predicted=4.985977, expected=5.030438
# predicted=4.977375, expected=4.997212
# predicted=4.949311, expected=4.919981
# predicted=4.982544, expected=4.897840
# predicted=4.938344, expected=4.948760
# predicted=4.922194, expected=4.787492
# predicted=4.878030, expected=4.762174
# predicted=4.832809, expected=4.709530
# predicted=4.753065, expected=4.709530
# predicted=4.727078, expected=4.753590
# predicted=4.724217, expected=4.828314
# predicted=4.763811, expected=4.442651
# Test RMSE: 0.167

# %%
from pandas import Series

stationary = difference(df['qtd'].values).dropna()
# stationary.index = series.index[1:]
# check if stationary
result = adfuller(stationary) 
print('ADF Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) # save
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-e4a8fac5bd84> in <module>()
#       1 from pandas import Series
#       2
# ----> 3 stationary = difference(df['qtd'].values).dropna()
#       4 # stationary.index = series.index[1:]
#       5 # check if stationary
#
# AttributeError: 'list' object has no attribute 'dropna'

# %% [markdown]
# ## Analizar order Arima

# %%
# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	X = X.astype('float32')
	train_size = int(len(X) * 0.85)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit(disp=0,transparams=False)
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	mse = mean_squared_error(test, predictions)
	rmse = sqrt(mse)
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					mse = evaluate_arima_model(dataset, order)
					if mse < best_score:
						best_score, best_cfg = mse, order
					print('ARIMA%s MSE=%.3f' % (order,mse))
				except:
					continue
	print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# load dataset

# evaluate parameters
p_values = range(0,6)
d_values = range(0, 4)
q_values = range(0, 6)
warnings.filterwarnings("ignore")

X, lam = boxcox(df['qtd'].values)
evaluate_models(X, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=4.923
# ARIMA(0, 0, 1) MSE=5.053
# ARIMA(0, 0, 2) MSE=4.047
# ARIMA(0, 0, 4) MSE=3.986
# ARIMA(0, 1, 0) MSE=3.762
# ARIMA(0, 1, 1) MSE=4.615
# ARIMA(0, 1, 2) MSE=5.955
# ARIMA(0, 2, 0) MSE=4.722
# ARIMA(0, 2, 1) MSE=3.548
# ARIMA(1, 0, 0) MSE=4.587
# ARIMA(1, 0, 1) MSE=6.091
# ARIMA(1, 1, 0) MSE=3.738
# ARIMA(1, 1, 1) MSE=4.284
# ARIMA(1, 1, 2) MSE=5.978
# ARIMA(1, 1, 3) MSE=5.635
# ARIMA(1, 2, 0) MSE=4.506
# ARIMA(1, 2, 3) MSE=3.541
# ARIMA(2, 0, 0) MSE=4.819
# ARIMA(2, 0, 1) MSE=7.418
# ARIMA(2, 1, 0) MSE=3.738
# ARIMA(2, 1, 1) MSE=4.002
# ARIMA(2, 1, 2) MSE=3.953
# ARIMA(2, 1, 3) MSE=4.047
# ARIMA(2, 2, 0) MSE=43782402629277000.000
# ARIMA(2, 2, 1) MSE=3.188
# ARIMA(2, 2, 2) MSE=3.040
# ARIMA(3, 0, 0) MSE=5.273
# ARIMA(3, 0, 1) MSE=5.726
# ARIMA(3, 0, 2) MSE=5.395
# ARIMA(3, 1, 0) MSE=3.702
# ARIMA(3, 1, 1) MSE=3.978
# ARIMA(3, 1, 2) MSE=3.965
# ARIMA(3, 1, 3) MSE=4.005
# ARIMA(3, 1, 4) MSE=4.345
# ARIMA(3, 1, 5) MSE=4.416
# ARIMA(3, 2, 0) MSE=3.889
# ARIMA(3, 2, 1) MSE=3.060
# ARIMA(3, 2, 2) MSE=3.060
# ARIMA(3, 2, 3) MSE=4.508
# ARIMA(4, 0, 0) MSE=5.448
# ARIMA(4, 0, 1) MSE=5.766
# ARIMA(4, 0, 2) MSE=4.377
# ARIMA(4, 0, 3) MSE=4.193
# ARIMA(4, 0, 4) MSE=4.155
# ARIMA(4, 0, 5) MSE=4.354
# ARIMA(4, 1, 0) MSE=3.744
# ARIMA(4, 1, 1) MSE=3.697
# ARIMA(4, 1, 2) MSE=3.849
# ARIMA(4, 1, 3) MSE=3.739
# ARIMA(4, 1, 4) MSE=4.390
# ARIMA(4, 1, 5) MSE=3.858
# ARIMA(4, 2, 0) MSE=3.797
# ARIMA(4, 2, 1) MSE=3.091
# ARIMA(4, 2, 2) MSE=3.301
# ARIMA(4, 2, 3) MSE=4.294
# ARIMA(5, 0, 0) MSE=5.591
# ARIMA(5, 0, 1) MSE=5.610
# ARIMA(5, 0, 2) MSE=4.178
# ARIMA(5, 0, 3) MSE=4.423
# ARIMA(5, 0, 4) MSE=4.462
# ARIMA(5, 0, 5) MSE=4.884
# ARIMA(5, 1, 0) MSE=1685222029.483
# ARIMA(5, 1, 1) MSE=3.751
# ARIMA(5, 1, 2) MSE=3.993
# ARIMA(5, 1, 3) MSE=3.684
# ARIMA(5, 1, 4) MSE=3.801
# ARIMA(5, 1, 5) MSE=3.938
# ARIMA(5, 2, 0) MSE=3.610
# ARIMA(5, 2, 1) MSE=3.258
# Best ARIMA(2, 2, 2) MSE=3.040

# %%
df['qtd'].values

# %%
diff = np.diff(df['qtd'].values)

# %%
np.r_[1141, diff].cumsum()

# %%
X = df['qtd'].values
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
