# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import requests 
import time
import datetime as dt
from numpy import log
import statsmodels.api as sm
import statsmodels.tsa as tsa
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from math import sqrt

from pandas.tools.plotting import autocorrelation_plot

# statistical modeling libraries
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from scipy.stats import boxcox
#from arch import arch_model


# remove warnings
import warnings
warnings.filterwarnings('ignore')


# %matplotlib inline
# Out:
# /Users/diogodil/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
def boxcox_inverse(value, lam):
	if lam == 0:
		return exp(value)
	return np.exp(np.log(lam * value + 1) / lam)

# %%
df = pd.read_csv('roubos.csv',index_col=0,parse_dates=True).sort_index()
df = df.loc[df['ano'] > 2012]
df = df.loc[df['bairro'] == 'SUDOESTE']
df.drop('bairro', axis=1, inplace=True)
df.drop('mes', axis=1, inplace=True)
df.drop('ano', axis=1, inplace=True)
df.drop('tipo', axis=1, inplace=True)
df.sort_index()
df.head()
# Out:
#             qtd
# 0
# 2013-01-01  213
# 2013-02-01  193
# 2013-03-01  260
# 2013-04-01  226
# 2013-05-01  210

# %%
def ts_diagnostics(y, lags=None, title='', filename=''):
    '''
    Calculate acf, pacf, qq plot and Augmented Dickey Fuller test for a given time series
    '''
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    # weekly moving averages (12 months window because of years)
    rolling_mean = pd.rolling_mean(y, window=12)
    rolling_std = pd.rolling_std(y, window=12)
    
    fig = plt.figure(figsize=(14, 12))
    layout = (3, 2)
    ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
    acf_ax = plt.subplot2grid(layout, (1, 0))
    pacf_ax = plt.subplot2grid(layout, (1, 1))
    qq_ax = plt.subplot2grid(layout, (2, 0))
    hist_ax = plt.subplot2grid(layout, (2, 1))
    
    # time series plot
    y.plot(ax=ts_ax)
    rolling_mean.plot(ax=ts_ax, color='crimson');
    rolling_std.plot(ax=ts_ax, color='darkslateblue');
    plt.legend(loc='best')
    ts_ax.set_title(title, fontsize=24);
    
    # acf and pacf
    smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
    smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5) 
    
    # qq plot
    sm.qqplot(y, line='s', ax=qq_ax)
    qq_ax.set_title('QQ Plot')
    
    # hist plot
    y.plot(ax=hist_ax, kind='hist', bins=25);
    hist_ax.set_title('Histogram');
    plt.tight_layout();
    
    #plot
    plt.show()
    
    # perform Augmented Dickey Fuller test
    print('Results of Dickey-Fuller test:')
    dftest = adfuller(y, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['test statistic', 'p-value', '# of lags', '# of observations'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
ts_diagnostics(df['qtd'], lags=30, title='Crimes Goiânia')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.936621
# p-value                  0.315034
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64

# %%
y_diff = np.diff(df['qtd'])
ts_diagnostics(y_diff, lags=30, title='Goiaânia diff', filename='adf_diff')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -1.224498e+01
# p-value                 9.830106e-23
# # of lags               0.000000e+00
# # of observations       5.800000e+01
# Critical Value (1%)    -3.548494e+00
# Critical Value (5%)    -2.912837e+00
# Critical Value (10%)   -2.594129e+00
# dtype: float64

# %%
y_log = np.log(df['qtd'])
ts_diagnostics(y_log, lags=30, title='Crimes na região CENTRAL Log')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.652130
# p-value                  0.455930
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64

# %%
y_log_diff = np.log(df['qtd']).diff().dropna()
ts_diagnostics(y_log_diff, lags=30, title='Goiânia Log Diff')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -1.226156e+01
# p-value                 9.054653e-23
# # of lags               0.000000e+00
# # of observations       5.800000e+01
# Critical Value (1%)    -3.548494e+00
# Critical Value (5%)    -2.912837e+00
# Critical Value (10%)   -2.594129e+00
# dtype: float64

# %%
y_log_diff2 = np.log(df['qtd']).diff().diff(12).dropna()

# %%
ts_diagnostics(y_log_diff2, lags=30, title='Goiânia Log 2')
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic         -5.740203e+00
# p-value                 6.301318e-07
# # of lags               3.000000e+00
# # of observations       4.300000e+01
# Critical Value (1%)    -3.592504e+00
# Critical Value (5%)    -2.931550e+00
# Critical Value (10%)   -2.604066e+00
# dtype: float64

# %%
df['qtd_box'], lam = boxcox(df['qtd'])
ts_diagnostics(df['qtd_box'].dropna(), lags=30, title='Crimes na região CENTRAL Boxcox')
print(lam)
# Out:
# No handles with labels found to put in legend.
# Results of Dickey-Fuller test:
# test statistic          -1.908223
# p-value                  0.328203
# # of lags                2.000000
# # of observations       57.000000
# Critical Value (1%)     -3.550670
# Critical Value (5%)     -2.913766
# Critical Value (10%)    -2.594624
# dtype: float64
# 0.8949119161171284

# %%
y_diff = np.diff(df['qtd'])

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(y_log_diff, order=(6, 1, 1))
model_fit = model.fit(disp=0)

# %%
forecast = model_fit.forecast(steps=12)[0]
print(forecast)
print(np.exp(np.r_[forecast].cumsum()))
# Out:
# [ 0.02898254 -0.09730343  0.03149814 -0.05050289 -0.06616626 -0.00404064
#  -0.08436276  0.00492141 -0.08639978 -0.02083057 -0.05794134 -0.04843227]
# [1.02940662 0.93396073 0.96384696 0.91637863 0.8577077  0.85424901
#  0.78513837 0.78901189 0.72370338 0.70878415 0.66888336 0.6372598 ]

# %%
np.exp(model_fit.predict(start='2017-01-01', end='2017-12-01').cumsum())
# Out:
# 2017-01-01    1.194369
# 2017-02-01    1.176507
# 2017-03-01    1.636219
# 2017-04-01    1.053571
# 2017-05-01    1.404226
# 2017-06-01    0.942553
# 2017-07-01    1.347769
# 2017-08-01    1.422269
# 2017-09-01    1.540095
# 2017-10-01    1.701582
# 2017-11-01    1.563773
# 2017-12-01    1.425002
# Freq: MS, dtype: float64

# %%
np.exp(np.log(df['2017-01-01':'2017-12-01']['qtd']).diff().cumsum())
# Out:
# 0
# 2017-01-01         NaN
# 2017-02-01    0.795082
# 2017-03-01    1.045082
# 2017-04-01    0.877049
# 2017-05-01    1.110656
# 2017-06-01    0.827869
# 2017-07-01    0.770492
# 2017-08-01    0.684426
# 2017-09-01    0.663934
# 2017-10-01    0.655738
# 2017-11-01    0.704918
# 2017-12-01    0.565574
# Name: qtd, dtype: float64

# %%
plt.rcParams['savefig.dpi'] = 120
plt.rcParams['figure.autolayout'] = False
plt.rcParams['figure.figsize'] = (16, 8)
plt.rcParams['axes.labelsize'] = 16
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titlesize'] = 20
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['font.size'] = 16
plt.rcParams['lines.linewidth'] = 3.0
plt.rcParams['lines.markersize'] = 8
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['text.usetex'] = False

# %%
def difference(dataset):
    diff = list()
    for i in range(1, len(dataset)):
        value = dataset[i] - dataset[i - 1]
        diff.append(value)
    return diff

teste_dif = np.float64(difference(df['qtd'].values))

# %% [markdown]
# ## Valores sem conversão

# %%
X = df['qtd'].values
size = int(len(X) * 0.85)
size
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(0, 0, 3))
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))

error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=227.018982, expected=214.000000
# predicted=253.367456, expected=271.000000
# predicted=238.411124, expected=202.000000
# predicted=228.541822, expected=188.000000
# predicted=157.075940, expected=167.000000
# predicted=167.913809, expected=162.000000
# predicted=172.061613, expected=160.000000
# predicted=148.886697, expected=172.000000
# predicted=168.733451, expected=138.000000
# Test MSE: 578.614
# Test RMSE: 24.054

# %% [markdown]
# ## Valores com log

# %%
X = y_log.values
size = int(len(X) * 0.85)
size
train, test = X[0:size], X[size:len(X)]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(1, 2, 1), freq = 'M')
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (np.exp(yhat), np.exp(obs)))

error = mean_squared_error(np.exp(test), np.exp(predictions))
rms = sqrt(mean_squared_error(np.exp(test),np.exp(predictions)))
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(np.exp(test))
plt.plot(np.exp(predictions), color='red')
plt.show()
# Out:
# predicted=222.040859, expected=214.000000
# predicted=228.024851, expected=271.000000
# predicted=240.485546, expected=202.000000
# predicted=197.227535, expected=188.000000
# predicted=167.009804, expected=167.000000
# predicted=149.597109, expected=162.000000
# predicted=148.384261, expected=160.000000
# predicted=152.279146, expected=172.000000
# predicted=159.394065, expected=138.000000
# Test MSE: 512.575
# Test RMSE: 22.640

# %% [markdown]
# ## Valores com BoxCox

# %%
X, lam = boxcox(df['qtd'].values)
X = X.astype('float32')
train_size = int(len(X) * 0.85)
train, test = X[0:train_size], X[train_size:]

# walk-foward validation
history = [x for x in train]
predictions = list()
for i in range(len(test)):
	# transform
	transformed, lam = boxcox(history)
	if lam < -5:
		transformed, lam = history, 1
	# predict
	model = ARIMA(transformed, order=(0, 0, 3))
	model_fit = model.fit(disp=0, transparams=False)
	yhat = model_fit.forecast()[0]
	# invert transformed prediction
	yhat = boxcox_inverse(yhat, lam)
	predictions.append(yhat)
	# observation
	obs = test[i]
	history.append(obs)
	print('>Predicted=%.3f, Expected=%.3f' % (yhat, obs))
# report performance
mse = mean_squared_error(boxcox_inverse(np.float64(test),lam),boxcox_inverse(np.float64(predictions),lam))
rmse = sqrt(mse)
print('RMSE: %.3f' % rmse)
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# >Predicted=142.010, Expected=134.944
# >Predicted=157.089, Expected=166.961
# >Predicted=148.951, Expected=128.096
# >Predicted=143.080, Expected=120.051
# >Predicted=102.663, Expected=107.865
# >Predicted=107.792, Expected=104.940
# >Predicted=109.984, Expected=103.767
# >Predicted=97.286, Expected=110.780
# >Predicted=107.735, Expected=90.763
# RMSE: 41.024

# %% [markdown]
# ## Valores com diff

# %%
X = df['qtd'].values
first = X[0]
X = np.diff(X)
X = X.astype('float32')
train_size = int(len(X) * 0.85)
train, test = X[0:train_size], X[train_size:]

# %%
history = [x for x in train.astype(float)]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(3, 0, 1))
    model_fit = model.fit(disp=0, transparams=False)
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
rms = sqrt(mean_squared_error(test, predictions))
print('Test MSE: %.3f' % error)
print('Test RMSE: %.3f' % rms)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
plt.show()
# Out:
# predicted=-12.543779, expected=-41.000000
# predicted=27.409939, expected=57.000000
# predicted=-17.483646, expected=-69.000000
# predicted=24.570649, expected=-14.000000
# predicted=0.982663, expected=-21.000000
# predicted=14.273948, expected=-5.000000
# predicted=1.580048, expected=-2.000000
# predicted=2.048542, expected=12.000000
# predicted=-1.774887, expected=-34.000000
# Test MSE: 870.221
# Test RMSE: 29.500

# %%
from numpy import mean
X = y_log.values
window = 3
history = [X[i] for i in range(window)]
test = [X[i] for i in range(window, len(X))]
predictions = list()
# walk forward over time steps in test
for t in range(len(test)):
    length = len(history)
    yhat = mean([history[i] for i in range(length-window,length)])
    obs = test[t]
    predictions.append(yhat)
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
rmse = sqrt(mean_squared_error(test, predictions)) 
print('Test RMSE: %.3f' % rmse)
# plot
plt.plot(test)
plt.plot(predictions, color='red')
# plt.show()
# # zoom plot
# plt.plot(test[:100])
# plt.plot(predictions[:100], color='red')
# plt.show()
# Out:
# predicted=5.394888, expected=5.420535
# predicted=5.414636, expected=5.347108
# predicted=5.442775, expected=5.484797
# predicted=5.417480, expected=5.153292
# predicted=5.328399, expected=5.429346
# predicted=5.355811, expected=5.049856
# predicted=5.210831, expected=5.123964
# predicted=5.201055, expected=5.164786
# predicted=5.112869, expected=5.293305
# predicted=5.194018, expected=5.533389
# predicted=5.330493, expected=5.356586
# predicted=5.394427, expected=5.468060
# predicted=5.452679, expected=5.590987
# predicted=5.471878, expected=5.683580
# predicted=5.580876, expected=5.513429
# predicted=5.595998, expected=5.459586
# predicted=5.552198, expected=5.347108
# predicted=5.440041, expected=5.480639
# predicted=5.429111, expected=5.493061
# predicted=5.440269, expected=5.318120
# predicted=5.430607, expected=5.241747
# predicted=5.350976, expected=5.257495
# predicted=5.272454, expected=5.342334
# predicted=5.280526, expected=5.525453
# predicted=5.375094, expected=5.468060
# predicted=5.445282, expected=5.817111
# predicted=5.603541, expected=5.613128
# predicted=5.632766, expected=5.743003
# predicted=5.724414, expected=5.598422
# predicted=5.651518, expected=5.726848
# predicted=5.689424, expected=5.620401
# predicted=5.648557, expected=5.420535
# predicted=5.589261, expected=5.568345
# predicted=5.536427, expected=5.652489
# predicted=5.547123, expected=5.707110
# predicted=5.642648, expected=5.605802
# predicted=5.655134, expected=5.541264
# predicted=5.618059, expected=5.501258
# predicted=5.549441, expected=5.686975
# predicted=5.576499, expected=5.549076
# predicted=5.579103, expected=5.624018
# predicted=5.620023, expected=5.713733
# predicted=5.628942, expected=5.793014
# predicted=5.710255, expected=5.669881
# predicted=5.725542, expected=5.505332
# predicted=5.656075, expected=5.497168
# predicted=5.557460, expected=5.267858
# predicted=5.423453, expected=5.541264
# predicted=5.435430, expected=5.365976
# predicted=5.391699, expected=5.602119
# predicted=5.503119, expected=5.308268
# predicted=5.425454, expected=5.236442
# predicted=5.382276, expected=5.117994
# predicted=5.220901, expected=5.087596
# predicted=5.147344, expected=5.075174
# predicted=5.093588, expected=5.147494
# predicted=5.103422, expected=4.927254
# Test RMSE: 0.156

# %%
from pandas import Series

def difference(dataset):
  diff = list()
  for i in range(1, len(dataset)):
    value = dataset[i] - dataset[i - 1]
    diff.append(value)
  return Series(diff)

stationary = difference(df['qtd'].values).dropna()
# stationary.index = series.index[1:]
# check if stationary
result = adfuller(stationary) 
print('ADF Statistic: %f' % result[0]) 
print('p-value: %f' % result[1]) 
print('Critical Values:')
for key, value in result[4].items():
    print('\t%s: %.3f' % (key, value)) # save
# Out:
# ADF Statistic: -12.244983
# p-value: 0.000000
# Critical Values:
# 	1%: -3.548
# 	5%: -2.913
# 	10%: -2.594

# %% [markdown]
# ## Analizar order Arima

# %%
# evaluate an ARIMA model for a given order (p,d,q) and return RMSE
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	X = X.astype('float32')
	train_size = int(len(X) * 0.85)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit(disp=0,transparams=False)
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	mse = mean_squared_error(test, predictions)
	rmse = sqrt(mse)
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					mse = evaluate_arima_model(dataset, order)
					if mse < best_score:
						best_score, best_cfg = mse, order
					print('ARIMA%s MSE=%.3f' % (order,mse))
				except:
					continue
	print('Best ARIMA%s MSE=%.3f' % (best_cfg, best_score))

# load dataset

# evaluate parameters
p_values = range(0,6)
d_values = range(0, 4)
q_values = range(0, 6)
warnings.filterwarnings("ignore")
X = df['qtd'].values
X = np.diff(X)
evaluate_models(X, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) MSE=36.239
# ARIMA(0, 0, 1) MSE=32.505
# ARIMA(0, 0, 2) MSE=31.876
# ARIMA(0, 0, 3) MSE=39.942
# ARIMA(0, 0, 5) MSE=37.842
# ARIMA(0, 1, 0) MSE=68.709
# ARIMA(0, 1, 1) MSE=35.580
# ARIMA(0, 2, 0) MSE=141.353
# ARIMA(0, 2, 1) MSE=69.392
# ARIMA(1, 0, 0) MSE=31.730
# ARIMA(1, 0, 1) MSE=31.729
# ARIMA(1, 1, 0) MSE=45.402
# ARIMA(1, 1, 1) MSE=33.645
# ARIMA(1, 1, 2) MSE=42.230
# ARIMA(1, 1, 4) MSE=32.611
# ARIMA(1, 1, 5) MSE=37.217
# ARIMA(1, 2, 0) MSE=88.365
# ARIMA(1, 2, 1) MSE=55.911
# ARIMA(2, 0, 0) MSE=31.165
# ARIMA(2, 0, 1) MSE=31.342
# ARIMA(2, 0, 2) MSE=32.174
# ARIMA(2, 0, 3) MSE=32.626
# ARIMA(2, 1, 0) MSE=44.293
# ARIMA(2, 1, 1) MSE=36.846
# ARIMA(2, 1, 2) MSE=35.663
# ARIMA(2, 1, 3) MSE=51.200
# ARIMA(2, 1, 4) MSE=37.981
# ARIMA(2, 1, 5) MSE=36.448
# ARIMA(2, 2, 0) MSE=76.312
# ARIMA(2, 2, 1) MSE=66.699
# ARIMA(3, 0, 0) MSE=5143735902804111.000
# ARIMA(3, 0, 1) MSE=29.818
# ARIMA(3, 0, 2) MSE=35.898
# ARIMA(3, 0, 3) MSE=39.887
# ARIMA(3, 1, 0) MSE=41.617
# ARIMA(3, 1, 1) MSE=38.383
# ARIMA(3, 1, 2) MSE=48.476
# ARIMA(3, 2, 0) MSE=69.493
# ARIMA(3, 2, 1) MSE=49.742
# ARIMA(4, 0, 0) MSE=31.178
# ARIMA(4, 0, 1) MSE=33.716
# ARIMA(4, 0, 2) MSE=36.321
# ARIMA(4, 0, 3) MSE=37.183
# ARIMA(4, 0, 4) MSE=47.583
# ARIMA(4, 1, 0) MSE=37.667
# ARIMA(4, 1, 1) MSE=39.064
# ARIMA(4, 1, 2) MSE=46.009
# ARIMA(4, 1, 3) MSE=39.871
# ARIMA(4, 1, 4) MSE=41.566
# ARIMA(4, 1, 5) MSE=40.369
# ARIMA(4, 2, 0) MSE=54.517
# ARIMA(4, 2, 1) MSE=50.713
# ARIMA(4, 2, 2) MSE=64.639
# ARIMA(4, 2, 3) MSE=58.590
# ARIMA(4, 2, 4) MSE=64.839
# ARIMA(5, 0, 0) MSE=30.044
# ARIMA(5, 0, 1) MSE=32.577
# ARIMA(5, 0, 2) MSE=34.790
# ARIMA(5, 0, 3) MSE=42.021
# ARIMA(5, 0, 4) MSE=52.125
# ARIMA(5, 0, 5) MSE=38.445
# ARIMA(5, 1, 0) MSE=38.692
# ARIMA(5, 1, 1) MSE=40.233
# ARIMA(5, 1, 2) MSE=47.650
# ARIMA(5, 2, 0) MSE=54.380
# Best ARIMA(3, 0, 1) MSE=29.818

# %%
df['qtd'].values
# Out:
# array([213, 193, 260, 226, 210, 241, 173, 228, 156, 168, 175, 199, 253,
#        212, 237, 268, 294, 248, 235, 210, 240, 243, 204, 189, 192, 209,
#        251, 237, 336, 274, 312, 270, 307, 276, 226, 262, 285, 301, 272,
#        255, 245, 295, 257, 277, 303, 328, 290, 246, 244, 194, 255, 214,
#        271, 202, 188, 167, 162, 160, 172, 138])

# %%
diff = np.diff(df['qtd'].values)

# %%
np.r_[1141, diff].cumsum()
# Out:
# array([1141, 1121, 1188, 1154, 1138, 1169, 1101, 1156, 1084, 1096, 1103,
#        1127, 1181, 1140, 1165, 1196, 1222, 1176, 1163, 1138, 1168, 1171,
#        1132, 1117, 1120, 1137, 1179, 1165, 1264, 1202, 1240, 1198, 1235,
#        1204, 1154, 1190, 1213, 1229, 1200, 1183, 1173, 1223, 1185, 1205,
#        1231, 1256, 1218, 1174, 1172, 1122, 1183, 1142, 1199, 1130, 1116,
#        1095, 1090, 1088, 1100, 1066])

# %%
X = df['qtd'].values
split = int(len(X) / 2)
X1, X2 = X[0:split], X[split:]
mean1, mean2 = X1.mean(), X2.mean()
var1, var2 = X1.var(), X2.var()
print('mean1=%f, mean2=%f' % (mean1, mean2))
print('variance1=%f, variance2=%f' % (var1, var2))
# Out:
# mean1=225.800000, mean2=245.800000
# variance1=1482.960000, variance2=2615.826667
